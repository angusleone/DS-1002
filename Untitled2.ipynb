# %%
# !pip install english_words
from english_words import get_english_words_set
import numpy as np
import matplotlib.pyplot as plt

#initial  type is a set

words = get_english_words_set(['web2'], lower=True)
wordlist = list(words)
len(wordlist)
# Out:
# ...
# 234450

# %%
print(wordlist[:10])
# Out:
# ['redesignate', 'celestinian', 'counterattractively', 'incoming', 'superunit', 'sandless', 'tricarballylic', 'denitrification', 'promammal', 'fleshment']

# %%
alpha_list = sorted(wordlist)
print(alpha_list[:10])
#10 words start with a
# no q's
# 7 e's
# Out:
# ['a', 'aa', 'aal', 'aalii', 'aam', 'aani', 'aardvark', 'aardwolf', 'aaron', 'aaronic']

# %%
wordlist_np = np.array(wordlist)
alpha_list_np = np.array(alpha_list)
alphabet = [chr(i) for i in range(ord('a'), ord('z')+1)]

# %%
six_longest_words = sorted(wordlist, key=len, reverse=True)[:6]
print("Six longest words:", six_longest_words)
# Out:
# Six longest words: ['antidisestablishmentarianism', 'formaldehydesulphoxylate', 'pathologicopsychological', 'thyroparathyroidectomize', 'scientificophilosophical', 'tetraiodophenolphthalein']

# %%
word_lengths = [len(word) for word in wordlist]
plt.figure(figsize=(10, 6))
plt.hist(word_lengths, bins=range(1, max(word_lengths) + 1), edgecolor='black')
plt.xlabel('Word Length')
plt.ylabel('Frequency')
plt.title('Histogram of Word Lengths')
plt.show()

# %%
letter_counts = {letter: sum(word.startswith(letter) for word in wordlist) for letter in alphabet}
plt.figure(figsize=(10, 6))
plt.bar(letter_counts.keys(), letter_counts.values())
plt.xlabel('Letter')
plt.ylabel('Number of Words')
plt.title('Number of Words Starting with Each Letter')
plt.show()
